# %% [markdown]
# ## Feature Selection Techniques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = "C:/Users/DEVENDRA/Desktop/ml_database_7/mobile_data.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores     ...       px_height  px_width   ram  sc_h  sc_w  \
# 0        188        2     ...              20       756  2549     9     7
# 1        136        3     ...             905      1988  2631    17     3
# 2        145        5     ...            1263      1716  2603    11     2
# 3        131        6     ...            1216      1786  2769    16     8
# 4        141        2     ...            1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ### Univariate feature

# %%
x = df.iloc[:,:-1]
y = df['price_range']

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
## apply selectkbest Algor
order_ranked_feat = SelectKBest(score_func=chi2, k=20 )
ordered_feat = order_ranked_feat.fit(x, y)

# %%
ordered_score = pd.DataFrame(ordered_feat.scores_, columns=['score'])
ordered_colu = pd.DataFrame(x.columns)

# %%
feature_imp = pd.concat([ordered_colu,ordered_score], axis = 1)

# %%
feature_imp.columns=['feature', 'Score']

# %%
feature_imp
# Out:
#           feature          Score
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
feature_imp.nlargest(10, 'Score')
# Out:
#           feature          Score
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# ### feature Importance
# this technique gives a score for each feature of data , highest the score more relevant it is

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06059736 0.01906463 0.03447267 0.01956346 0.03176513 0.0182444
#  0.03466597 0.03391546 0.0362239  0.0336032  0.03468306 0.04768985
#  0.04978524 0.39008468 0.0338645  0.03354549 0.03482215 0.01505148
#  0.01770275 0.02065462]

# %%
rank_feat = pd.Series(model.feature_importances_, index= x.columns)
rank_feat.nlargest(10).plot(kind='barh')

# %% [markdown]
# ## correlation

# %%
import seaborn as sns
corr = df.corr() ## all the feature with dependent feature
corre = df.iloc[:,:-1].corr()

# %%
corre
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
top_feature = corr.index
plt.figure(figsize = (20,20))
sns.heatmap(df[top_feature].corr(), annot = True)

# %%
top_feature = corre.index
plt.figure(figsize = (20,20))
sns.heatmap(df[top_feature].corr(), annot = True)

# %%
## find and remove correleation feature
threshold = 0.5
def correlation(df, threshold):
    col_corr = set() # set all the name of correlated columns
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i] # getting the name of the columns
                col_corr.add(colname)
    return col_corr

# %%
correlation(df.iloc[:,:-1], threshold)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}

# %% [markdown]
# ## Infromation Gane

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info_classif(x, y)
# Out:
# array([0.02724934, 0.        , 0.00342887, 0.        , 0.01323388,
#        0.00432681, 0.0108583 , 0.00858946, 0.        , 0.00806032,
#        0.00478422, 0.02435496, 0.02840119, 0.84684768, 0.00775509,
#        0.        , 0.        , 0.        , 0.        , 0.00432106])

# %%
mutual_data = mutual_info_classif(x, y)

# %%
mutual_data = pd.Series(mutual_data, index = x.columns)
mutual_data.sort_values(ascending = False)
# Out:
# ram              0.852284
# px_width         0.029249
# battery_power    0.027128
# px_height        0.026264
# sc_w             0.024294
# n_cores          0.020136
# sc_h             0.016299
# blue             0.013402
# fc               0.011561
# four_g           0.011543
# three_g          0.008134
# dual_sim         0.007226
# int_memory       0.007205
# mobile_wt        0.006017
# pc               0.000452
# talk_time        0.000000
# touch_screen     0.000000
# m_dep            0.000000
# clock_speed      0.000000
# wifi             0.000000
# dtype: float64
